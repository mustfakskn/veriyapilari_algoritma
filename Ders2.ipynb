# %% [markdown]
# ## ***Veri yapıları ve algoritma dersi 2.gün // Değişkenler ve Veri tipleri ***

# %%
print("Merhaba Dünya || Ders 2")
# Out:
# Merhaba Dünya || Ders 2

# %%
import sys # Import python programlama dilinde yazılıma kütüphane eklemeye yarayan kod blogudur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # Google colab - Drive Bağlantısı
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd #bize kodun çıktısını dosya yolu olarak çıktısını veren kod blogudur.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA

# %%
sayi1=5
Deger2=10
sayi_3=21

print(sayi1)
print(Deger2)
print(sayi_3)
# Out:
# 5
# 10
# 21

# %%
x='Merhaba Dünya'
y=100

print(x)
print(y)
# Out:
# Merhaba Dünya
# 100

# %%
# integer - tam sayı tanımlaması
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
# float - ondalıklı sayı tanımlaması
x=30.1
print(type(x))
# Out:
# <class 'float'>

# %%
# int'ten float'a çevrimin gerçekleştirilmesi
x=10
y=float(x)
print(y,type(y))
# Out:
# 10.0 <class 'float'>

# %%
# float'tan integer'e çevrimin gerçekleştirilmesi
z=9.7
k=int(z)
print(k,type(k))
# Out:
# 9 <class 'int'>

# %%
# String - Metinsel içerik tanımlaması
metin="veri yapıları"
print(metin)
print(type(metin))
# Out:
# veri yapıları
# <class 'str'>

# %%
# Boolean (True - False) - Doğru / Yanlış tanımlaması
d=True
c=False
print(d)
print(type(c))
# Out:
# True
# <class 'bool'>

# %%
# List - Liste tanımlaması
küme=[1,2,3,4,5]
print(küme)
print(type(küme))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
# Tuple - Demet tanımlaması
demet=('kırmızı','mavi','siyah')
print(demet)
print(type(demet))
# Out:
# ('kırmızı', 'mavi', 'siyah')
# <class 'tuple'>

# %% [markdown]
# Dictionary - Sözlük Nedir?
#
#
#
# 1.   Sözlükler, anahtar-değer (key-value) çiftlerini depolayan veri yapılarıdır.
# 2.   Her anahtar benzersizdir ve bir değere karşılık gelir.
# 3.   Sözlükler sırasızdır ve değiştirilebilir.
#
#   Sözlük Metotları ;
#
# *   keys(): Sözlüğün anahtarlarını döner.
# *   values(): Sözlüğün değerlerini döner.
# *   items(): Sözlüğün anahtar-değer çiftlerini döner.

# %%
# Dictionary - Sözlük Örneği -> Öğrencilerin notlarını tutan bir sözlük
notlar = {
    "Ali": 85,
    "Veli": 90,
    "Ayşe": 78
}

notlar["Fatma"] = 92 # Yeni öğrenci ekleme
notlar["Mustafa"] = 100 # Öğrencinin notunu güncelleme

notlar["Ali"] = 88 # Bir öğrencinin notunu güncelleme

print(notlar)
# Out:
# {'Ali': 88, 'Veli': 90, 'Ayşe': 78, 'Fatma': 92, 'Mustafa': 100}

# %%
print(notlar.keys())
print(notlar.values())
print(notlar.items())
# Out:
# dict_keys(['Ali', 'Veli', 'Ayşe', 'Fatma', 'Mustafa'])
# dict_values([88, 90, 78, 92, 100])
# dict_items([('Ali', 88), ('Veli', 90), ('Ayşe', 78), ('Fatma', 92), ('Mustafa', 100)])

# %% [markdown]
# Set - Küme Nedir?
#
# 1.  Kümeler, benzersiz elemanlardan oluşan sırasız koleksiyonlardır.
# 2.  Kümeler değiştirilebilir ve tekrarlayan eleman içermez.
#
# Küme Metotları;
#
# *   add(): Küme içerisine eleman ekler.
# *   remove(): Küme içerisinden eleman siler.
# *   union(): İki kümenin birleşimini döner.
# *   intersection(): İki kümenin kesişimini döner.
# *   difference(): İki kümenin farkını döner.

# %%
# Set - Küme Örneği -> Bir yazılım etkinliğine katılan kişilerin oluşturduğu kümeler
kodyazanlar = {"Ahmet", "Mehmet", "Ayşe"}
kodyazmayanlar = {"Ayşe", "Fatma", "Veli"}

# Kafasına Göre Takılan Öğrenciler
ortak = kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına Göre Takılan Öğrencilerin Listesi:", ortak)

# Etkinlikte Kod Çalışması Yapmayan Öğrencilerin Tespiti
Kod_yazmayan = kodyazmayanlar.difference(kodyazanlar)
print("Kod çalışması yapmayan öğrenci listesi:", Kod_yazmayan)

# Yazılım Eğitiminin Öğrenci İmza Listesi
imza_listesi = kodyazanlar.union(kodyazmayanlar)
print("Etkinlik katılımcıları:", imza_listesi)
# Out:
# Kafasına Göre Takılan Öğrencilerin Listesi: {'Ayşe'}
# Kod çalışması yapmayan öğrenci listesi: {'Fatma', 'Veli'}
# Etkinlik katılımcıları: {'Ahmet', 'Mehmet', 'Fatma', 'Veli', 'Ayşe'}

# %%
giris = input("Bir sayı girin: ")
try:
    num = float(giris)
    print(f"Girilen sayı: {num}, tipi: {type(num)},", abs(num))
except ValueError:
    print("Geçersiz veri girdiniz.")
# Out:
# Bir sayı girin: 100
# Girilen sayı: 100.0, tipi: <class 'float'>, 100.0

# %%
 # 0 ile 1 arasında rastgele bir ondalık sayı üretir
import random
rastgele_float=random.random()
print("Rastgele Değer:",rastgele_float)
# Out:
# Rastgele Değer: 0.3771916911105566

# %%
# 1 ile 10 arasında (her iki sınır dahil) rastgele bir tam sayı üretir
import random
rastgele_sayi=random.randint(1,10)
print("Rastgele Sayı:",rastgele_sayi)
# Out:
# Rastgele Sayı: 9
